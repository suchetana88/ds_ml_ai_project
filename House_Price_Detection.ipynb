# %% [markdown]
# #### Get required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data = pd.read_csv("train.csv")

# %%
train_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
train_data.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
plt.bar("MSZoning", "SalePrice", data = train_data, color = "red")
plt.xlabel("Zone")
plt.ylabel("Price")
plt.title("Zone Wise House Sale Price")
plt.show()

# %%
# train_data.MSSubClass = train_data.MSSubClass.astype('object')

# %%
# plt.figure(figsize=(20,10))
# plt.bar("MSSubClass", "SalePrice", data = train_data, color = "red")
# plt.xlabel("BuildingType")
# plt.ylabel("Price")
# plt.title("Building Type Wise House Sale Price")
# plt.show()

# %%
plt.bar("Street", "SalePrice", data = train_data, color = "red")
plt.xlabel("Street")
plt.ylabel("Price")
plt.title("Street Access Wise House Sale Price")
plt.show()

# %%
plt.bar("Utilities", "SalePrice", data = train_data, color = "red")
plt.xlabel("Utilities")
plt.ylabel("Price")
plt.title("Utility Wise House Sale Price")
plt.show()

# %%
# Get a series of unique values in column 'Uttility' of the dataframe
Utilities = train_data['Utilities'].unique()
Utilities
# Out:
# array(['AllPub', 'NoSeWa'], dtype=object)

# %%
# Get a series of unique values in column 'Age' of the dataframe
Utilities = train_data['Fence'].unique()
Utilities
# Out:
# array([nan, 'MnPrv', 'GdWo', 'GdPrv', 'MnWw'], dtype=object)

# %%
train_data.describe()
# Out:
#                 Id  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean    730.500000    70.049958   10516.828082     6.099315     5.575342
# std     421.610009    24.284752    9981.264932     1.382997     1.112799
# min       1.000000    21.000000    1300.000000     1.000000     1.000000
# 25%     365.750000    59.000000    7553.500000     5.000000     5.000000
# 50%     730.500000    69.000000    9478.500000     6.000000     5.000000
# 75%    1095.250000    80.000000   11601.500000     7.000000     6.000000
# max    1460.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# ...

# %%
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x=train_data["SalePrice"])
